# %% [markdown]
# <a href="https://colab.research.google.com/github/KorotkovNikita/PDA_SOL/blob/main/%D0%A1%D0%A01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Выполнил Коротков Н.А.

# %% [markdown]
# [1] Написать цикл для выведения на экран каждой буквы своего ФИО

# %%
name = "Коротков Никита Андреевич"
for letter in name:
    print(letter)

# %% [markdown]
# [2]  Написать функцию для перевода рубля в йену c округлением до 2х знаков после запятой

# %%
def rub_to_yen(SumRub):#перевод рублей в йены
 Rate=1.56 #курс валюты
 SumYen= SumRub*Rate
 return round(SumYen,2)

rub_to_yen(4678) #Суммв в рублях для перевода
